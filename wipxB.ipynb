# %% [markdown]
# https://statsbomb.com/soccer-metrics/expected-goals-xg-explained/
#
# So, above is the "expected goals" aka xG metric, which is fairly new in the world of football. Knowing the definition and how it works, so here's TLDR version if you're not up for a lesson:
#
# xG stands for expected goals and is a statistical measure that quantifies the quality of goal-scoring chances in a football match. It provides a numerical value between 0 and 1 to each scoring opportunity, representing the likelihood of a goal being scored from that chance.
#
# xG takes into account various factors such as the location of the shot, the angle, the distance from the goal, the body part used to shoot, and sometimes additional factors like the number of defenders in the way or the assist type. By analyzing large amounts of historical data, statisticians and analysts can assign probabilities to each type of chance.
#
# This metric is valuable because it helps to assess the performance of a team or player beyond just the number of goals scored. It provides a more accurate picture of the quality of scoring opportunities created or conceded, allowing for a better understanding of a team's attacking or defensive effectiveness. xG is widely used in modern football analysis and is often referenced in match reports, player evaluations, and tactical discussions.
#
#
# Is there a chance to introduce xB as "expected baskets" in basketball? What metrics should we use?

# %% [markdown]
# ### 1. Defining a function to calculate xB

# %%
def calculate_xB(shots_data):
    total_xB = 0
    # Iretate thru each shot in database
    for shot in shots_data:
        xB = calculate_shot_xB(shot)
        total_xB += xB
    return total_xB

# %% [markdown]
# ### 2. Defining a function to calculate xB value for a specific shot

# %%
def calculate_shot_xB(shot):
    # Perform calculations to determine xB for each shot
    # Factors to consider may include shot distance, shot type, defender proximity, etc.
    xB = 0.5  # Placeholder value, replace with actual calculation

    return xB

# %% [markdown]
# ### 3. Sample database

# %%
# Example usage
shots_data = [
    {'distance': 5, 'type': 'layup', 'defender_distance': 2},
    {'distance': 20, 'type': 'jump shot', 'defender_distance': 1},
    # Add more shot data as needed
]

# %% [markdown]
# ### 4. Add more sample data to the database with randomizer

# %%
import random

def generate_random_shot():
    distance = random.randint(1, 30)
    types = ['layup', 'jump shot', 'dunk', 'three-pointer']  # Add more types as needed
    defender_distance = random.randint(1, 10)
    
    shot_result = random.choices(['scored', 'missed'], weights=[0.65, 0.35])[0]
    team = random.choices(['home', 'away'], weights=[0.55, 0.45])[0]
    
    return {'distance': distance, 'type': random.choice(types), 'defender_distance': defender_distance, 'result': shot_result, 'team': team}

# Generate 5000 random shots
shots_data = []
for _ in range(5000):
    shot = generate_random_shot()
    shots_data.append(shot)

# Print the generated shots data
for i, shot in enumerate(shots_data):
    print(f"Shot {i + 1}: {shot}")
# Out:
# Shot 1: {'distance': 2, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 2: {'distance': 9, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 3: {'distance': 1, 'type': 'dunk', 'defender_distance': 5, 'result': 'missed', 'team': 'home'}
# Shot 4: {'distance': 4, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 5: {'distance': 26, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 6: {'distance': 12, 'type': 'dunk', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 7: {'distance': 4, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 8: {'distance': 24, 'type': 'layup', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 9: {'distance': 18, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 10: {'distance': 15, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 11: {'distance': 3, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 12: {'distance': 14, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 13: {'distance': 15, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 14: {'distance': 15, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 15: {'distance': 9, 'type': 'layup', 'defender_distance': 2, 'result': 'missed', 'team': 'away'}
# Shot 16: {'distance': 26, 'type': 'layup', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 17: {'distance': 9, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 18: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 19: {'distance': 8, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 20: {'distance': 25, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 21: {'distance': 17, 'type': 'layup', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 22: {'distance': 7, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 23: {'distance': 20, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 24: {'distance': 15, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 25: {'distance': 5, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 26: {'distance': 8, 'type': 'dunk', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 27: {'distance': 9, 'type': 'jump shot', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 28: {'distance': 19, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 29: {'distance': 18, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 30: {'distance': 4, 'type': 'dunk', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 31: {'distance': 24, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 32: {'distance': 19, 'type': 'dunk', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 33: {'distance': 14, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 34: {'distance': 5, 'type': 'jump shot', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 35: {'distance': 17, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 36: {'distance': 25, 'type': 'jump shot', 'defender_distance': 5, 'result': 'missed', 'team': 'home'}
# Shot 37: {'distance': 9, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 38: {'distance': 14, 'type': 'dunk', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 39: {'distance': 15, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 40: {'distance': 4, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 41: {'distance': 20, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 42: {'distance': 9, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 43: {'distance': 22, 'type': 'layup', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 44: {'distance': 23, 'type': 'dunk', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 45: {'distance': 4, 'type': 'layup', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 46: {'distance': 17, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 47: {'distance': 18, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 48: {'distance': 14, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 49: {'distance': 13, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 50: {'distance': 25, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 51: {'distance': 4, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 52: {'distance': 15, 'type': 'jump shot', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 53: {'distance': 28, 'type': 'dunk', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 54: {'distance': 21, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 55: {'distance': 15, 'type': 'dunk', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 56: {'distance': 30, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 57: {'distance': 6, 'type': 'dunk', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 58: {'distance': 22, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 59: {'distance': 30, 'type': 'layup', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 60: {'distance': 11, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 61: {'distance': 8, 'type': 'jump shot', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 62: {'distance': 26, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 63: {'distance': 17, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 64: {'distance': 19, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 65: {'distance': 17, 'type': 'dunk', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 66: {'distance': 21, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 67: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 68: {'distance': 24, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 69: {'distance': 18, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 70: {'distance': 28, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 71: {'distance': 28, 'type': 'dunk', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 72: {'distance': 12, 'type': 'dunk', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 73: {'distance': 20, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 74: {'distance': 27, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 75: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 76: {'distance': 16, 'type': 'dunk', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 77: {'distance': 17, 'type': 'jump shot', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 78: {'distance': 6, 'type': 'dunk', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 79: {'distance': 21, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 80: {'distance': 9, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'away'}
# Shot 81: {'distance': 6, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 82: {'distance': 11, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 83: {'distance': 20, 'type': 'jump shot', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 84: {'distance': 3, 'type': 'dunk', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 85: {'distance': 9, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 86: {'distance': 29, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 87: {'distance': 19, 'type': 'layup', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 88: {'distance': 16, 'type': 'layup', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 89: {'distance': 18, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 90: {'distance': 1, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 91: {'distance': 16, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 92: {'distance': 4, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 93: {'distance': 7, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 94: {'distance': 17, 'type': 'layup', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 95: {'distance': 28, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 96: {'distance': 19, 'type': 'dunk', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 97: {'distance': 16, 'type': 'jump shot', 'defender_distance': 6, 'result': 'missed', 'team': 'away'}
# Shot 98: {'distance': 3, 'type': 'dunk', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 99: {'distance': 12, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 100: {'distance': 3, 'type': 'layup', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 101: {'distance': 2, 'type': 'layup', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 102: {'distance': 14, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 103: {'distance': 9, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 104: {'distance': 28, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 105: {'distance': 10, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 106: {'distance': 17, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 107: {'distance': 20, 'type': 'dunk', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 108: {'distance': 12, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 109: {'distance': 2, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 110: {'distance': 25, 'type': 'dunk', 'defender_distance': 5, 'result': 'missed', 'team': 'home'}
# Shot 111: {'distance': 7, 'type': 'jump shot', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 112: {'distance': 26, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 113: {'distance': 6, 'type': 'dunk', 'defender_distance': 10, 'result': 'missed', 'team': 'away'}
# Shot 114: {'distance': 22, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 115: {'distance': 14, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 116: {'distance': 7, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 117: {'distance': 5, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 118: {'distance': 18, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 119: {'distance': 17, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 120: {'distance': 17, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 121: {'distance': 4, 'type': 'dunk', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 122: {'distance': 29, 'type': 'jump shot', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 123: {'distance': 11, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 124: {'distance': 12, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 125: {'distance': 9, 'type': 'jump shot', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 126: {'distance': 16, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 127: {'distance': 1, 'type': 'dunk', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 128: {'distance': 27, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 129: {'distance': 6, 'type': 'dunk', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 130: {'distance': 20, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 131: {'distance': 10, 'type': 'jump shot', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 132: {'distance': 17, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 133: {'distance': 10, 'type': 'dunk', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 134: {'distance': 24, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 135: {'distance': 13, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 136: {'distance': 7, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 137: {'distance': 29, 'type': 'layup', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 138: {'distance': 2, 'type': 'dunk', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 139: {'distance': 9, 'type': 'layup', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 140: {'distance': 3, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 141: {'distance': 18, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 142: {'distance': 2, 'type': 'layup', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 143: {'distance': 28, 'type': 'jump shot', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 144: {'distance': 12, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 145: {'distance': 1, 'type': 'layup', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 146: {'distance': 4, 'type': 'layup', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 147: {'distance': 15, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 148: {'distance': 26, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 149: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 150: {'distance': 17, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 151: {'distance': 15, 'type': 'layup', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 152: {'distance': 22, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 153: {'distance': 29, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 154: {'distance': 1, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 155: {'distance': 14, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 156: {'distance': 15, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 157: {'distance': 4, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 158: {'distance': 17, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 159: {'distance': 16, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 160: {'distance': 1, 'type': 'layup', 'defender_distance': 2, 'result': 'missed', 'team': 'away'}
# Shot 161: {'distance': 19, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 162: {'distance': 14, 'type': 'jump shot', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 163: {'distance': 23, 'type': 'dunk', 'defender_distance': 5, 'result': 'missed', 'team': 'home'}
# Shot 164: {'distance': 26, 'type': 'jump shot', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 165: {'distance': 8, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 166: {'distance': 26, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 167: {'distance': 29, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 168: {'distance': 21, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 169: {'distance': 11, 'type': 'jump shot', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 170: {'distance': 11, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 171: {'distance': 23, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 172: {'distance': 9, 'type': 'jump shot', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 173: {'distance': 16, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 174: {'distance': 11, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 175: {'distance': 11, 'type': 'layup', 'defender_distance': 2, 'result': 'missed', 'team': 'home'}
# Shot 176: {'distance': 5, 'type': 'dunk', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 177: {'distance': 6, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 178: {'distance': 15, 'type': 'layup', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 179: {'distance': 7, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 180: {'distance': 9, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 181: {'distance': 4, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 182: {'distance': 18, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 183: {'distance': 4, 'type': 'dunk', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 184: {'distance': 8, 'type': 'layup', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 185: {'distance': 11, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 186: {'distance': 16, 'type': 'dunk', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 187: {'distance': 3, 'type': 'dunk', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 188: {'distance': 19, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 189: {'distance': 19, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 190: {'distance': 6, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 191: {'distance': 4, 'type': 'dunk', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 192: {'distance': 26, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 193: {'distance': 17, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 194: {'distance': 12, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 195: {'distance': 18, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 196: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 197: {'distance': 18, 'type': 'jump shot', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 198: {'distance': 1, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 199: {'distance': 3, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 200: {'distance': 12, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 201: {'distance': 19, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 202: {'distance': 11, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 203: {'distance': 27, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 204: {'distance': 8, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 205: {'distance': 14, 'type': 'jump shot', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 206: {'distance': 13, 'type': 'jump shot', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 207: {'distance': 26, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 208: {'distance': 20, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 209: {'distance': 28, 'type': 'dunk', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 210: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 211: {'distance': 5, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 212: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 213: {'distance': 2, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 214: {'distance': 13, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 215: {'distance': 23, 'type': 'dunk', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 216: {'distance': 10, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 217: {'distance': 27, 'type': 'dunk', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 218: {'distance': 5, 'type': 'dunk', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 219: {'distance': 5, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 220: {'distance': 3, 'type': 'dunk', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 221: {'distance': 10, 'type': 'layup', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 222: {'distance': 25, 'type': 'layup', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 223: {'distance': 2, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 224: {'distance': 30, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 225: {'distance': 3, 'type': 'layup', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 226: {'distance': 6, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 227: {'distance': 14, 'type': 'dunk', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 228: {'distance': 15, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 229: {'distance': 19, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 230: {'distance': 16, 'type': 'layup', 'defender_distance': 2, 'result': 'missed', 'team': 'away'}
# Shot 231: {'distance': 23, 'type': 'layup', 'defender_distance': 10, 'result': 'missed', 'team': 'away'}
# Shot 232: {'distance': 14, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 233: {'distance': 20, 'type': 'jump shot', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 234: {'distance': 22, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 235: {'distance': 6, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 236: {'distance': 13, 'type': 'dunk', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 237: {'distance': 21, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 238: {'distance': 3, 'type': 'layup', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 239: {'distance': 29, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 240: {'distance': 30, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 241: {'distance': 11, 'type': 'dunk', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 242: {'distance': 5, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 243: {'distance': 26, 'type': 'layup', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 244: {'distance': 13, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 245: {'distance': 2, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 246: {'distance': 4, 'type': 'jump shot', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 247: {'distance': 15, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 248: {'distance': 18, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 249: {'distance': 21, 'type': 'jump shot', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 250: {'distance': 26, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 251: {'distance': 3, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 252: {'distance': 15, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 253: {'distance': 25, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 254: {'distance': 25, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 255: {'distance': 26, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 256: {'distance': 29, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 257: {'distance': 2, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 258: {'distance': 16, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 259: {'distance': 28, 'type': 'dunk', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 260: {'distance': 1, 'type': 'jump shot', 'defender_distance': 2, 'result': 'missed', 'team': 'home'}
# Shot 261: {'distance': 9, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 262: {'distance': 1, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 263: {'distance': 4, 'type': 'jump shot', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 264: {'distance': 18, 'type': 'jump shot', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 265: {'distance': 3, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 266: {'distance': 4, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 267: {'distance': 21, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 268: {'distance': 1, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 269: {'distance': 20, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 270: {'distance': 28, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 271: {'distance': 13, 'type': 'jump shot', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 272: {'distance': 16, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 273: {'distance': 25, 'type': 'dunk', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 274: {'distance': 21, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 275: {'distance': 1, 'type': 'layup', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 276: {'distance': 12, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 277: {'distance': 28, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 278: {'distance': 15, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 279: {'distance': 10, 'type': 'layup', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 280: {'distance': 14, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 281: {'distance': 5, 'type': 'layup', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 282: {'distance': 14, 'type': 'jump shot', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 283: {'distance': 23, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 284: {'distance': 18, 'type': 'dunk', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 285: {'distance': 30, 'type': 'dunk', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 286: {'distance': 24, 'type': 'layup', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 287: {'distance': 8, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 288: {'distance': 30, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 289: {'distance': 17, 'type': 'dunk', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 290: {'distance': 10, 'type': 'dunk', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 291: {'distance': 2, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 292: {'distance': 12, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 293: {'distance': 7, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'away'}
# Shot 294: {'distance': 5, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 295: {'distance': 27, 'type': 'dunk', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 296: {'distance': 2, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 297: {'distance': 25, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 298: {'distance': 21, 'type': 'jump shot', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 299: {'distance': 26, 'type': 'dunk', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 300: {'distance': 3, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 301: {'distance': 27, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 302: {'distance': 25, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 303: {'distance': 12, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 304: {'distance': 23, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 305: {'distance': 5, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 306: {'distance': 30, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 307: {'distance': 25, 'type': 'layup', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 308: {'distance': 17, 'type': 'jump shot', 'defender_distance': 10, 'result': 'missed', 'team': 'away'}
# Shot 309: {'distance': 26, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'missed', 'team': 'away'}
# Shot 310: {'distance': 12, 'type': 'dunk', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 311: {'distance': 10, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 312: {'distance': 16, 'type': 'dunk', 'defender_distance': 2, 'result': 'missed', 'team': 'away'}
# Shot 313: {'distance': 12, 'type': 'dunk', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 314: {'distance': 15, 'type': 'dunk', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 315: {'distance': 3, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 316: {'distance': 30, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 317: {'distance': 22, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 318: {'distance': 15, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 319: {'distance': 21, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 320: {'distance': 11, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 321: {'distance': 21, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 322: {'distance': 6, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 323: {'distance': 11, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 324: {'distance': 4, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 325: {'distance': 14, 'type': 'jump shot', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 326: {'distance': 23, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 327: {'distance': 23, 'type': 'dunk', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 328: {'distance': 2, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 329: {'distance': 27, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 330: {'distance': 15, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 331: {'distance': 19, 'type': 'dunk', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 332: {'distance': 4, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 333: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'missed', 'team': 'away'}
# Shot 334: {'distance': 21, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 335: {'distance': 15, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 336: {'distance': 2, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'away'}
# Shot 337: {'distance': 30, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 338: {'distance': 15, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 339: {'distance': 9, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 340: {'distance': 21, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 341: {'distance': 6, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 342: {'distance': 6, 'type': 'layup', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 343: {'distance': 16, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 344: {'distance': 6, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 345: {'distance': 16, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 346: {'distance': 30, 'type': 'dunk', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 347: {'distance': 19, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 348: {'distance': 3, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 349: {'distance': 20, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 350: {'distance': 7, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 351: {'distance': 20, 'type': 'jump shot', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 352: {'distance': 9, 'type': 'dunk', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 353: {'distance': 20, 'type': 'jump shot', 'defender_distance': 5, 'result': 'missed', 'team': 'home'}
# Shot 354: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 355: {'distance': 20, 'type': 'jump shot', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 356: {'distance': 23, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 357: {'distance': 22, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 358: {'distance': 8, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 359: {'distance': 3, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 360: {'distance': 18, 'type': 'dunk', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 361: {'distance': 19, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 362: {'distance': 22, 'type': 'dunk', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 363: {'distance': 21, 'type': 'layup', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 364: {'distance': 16, 'type': 'dunk', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 365: {'distance': 17, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 366: {'distance': 24, 'type': 'dunk', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 367: {'distance': 6, 'type': 'dunk', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 368: {'distance': 9, 'type': 'jump shot', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 369: {'distance': 18, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 370: {'distance': 8, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 371: {'distance': 15, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 372: {'distance': 22, 'type': 'layup', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 373: {'distance': 23, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 374: {'distance': 2, 'type': 'jump shot', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 375: {'distance': 11, 'type': 'layup', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 376: {'distance': 22, 'type': 'jump shot', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 377: {'distance': 13, 'type': 'dunk', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 378: {'distance': 7, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 379: {'distance': 24, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 380: {'distance': 11, 'type': 'layup', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 381: {'distance': 19, 'type': 'jump shot', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 382: {'distance': 7, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 383: {'distance': 4, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 384: {'distance': 17, 'type': 'dunk', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 385: {'distance': 26, 'type': 'jump shot', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 386: {'distance': 25, 'type': 'layup', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 387: {'distance': 11, 'type': 'jump shot', 'defender_distance': 5, 'result': 'missed', 'team': 'away'}
# Shot 388: {'distance': 26, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 389: {'distance': 7, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 390: {'distance': 28, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 391: {'distance': 3, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 392: {'distance': 17, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 393: {'distance': 29, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 394: {'distance': 5, 'type': 'layup', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 395: {'distance': 4, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 396: {'distance': 21, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 397: {'distance': 7, 'type': 'dunk', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 398: {'distance': 26, 'type': 'jump shot', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 399: {'distance': 23, 'type': 'dunk', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 400: {'distance': 4, 'type': 'jump shot', 'defender_distance': 5, 'result': 'missed', 'team': 'home'}
# Shot 401: {'distance': 9, 'type': 'jump shot', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 402: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 403: {'distance': 5, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 404: {'distance': 10, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 405: {'distance': 1, 'type': 'layup', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 406: {'distance': 29, 'type': 'dunk', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 407: {'distance': 21, 'type': 'jump shot', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 408: {'distance': 21, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'home'}
# Shot 409: {'distance': 14, 'type': 'dunk', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 410: {'distance': 8, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'missed', 'team': 'away'}
# Shot 411: {'distance': 3, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 412: {'distance': 26, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 413: {'distance': 30, 'type': 'jump shot', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 414: {'distance': 7, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 415: {'distance': 2, 'type': 'jump shot', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 416: {'distance': 26, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 417: {'distance': 22, 'type': 'jump shot', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 418: {'distance': 27, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 419: {'distance': 8, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 420: {'distance': 26, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 421: {'distance': 4, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 422: {'distance': 28, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 423: {'distance': 22, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 424: {'distance': 24, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 425: {'distance': 4, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 426: {'distance': 9, 'type': 'jump shot', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 427: {'distance': 25, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 428: {'distance': 24, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 429: {'distance': 16, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 430: {'distance': 4, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 431: {'distance': 22, 'type': 'jump shot', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 432: {'distance': 14, 'type': 'jump shot', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 433: {'distance': 18, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 434: {'distance': 23, 'type': 'jump shot', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 435: {'distance': 28, 'type': 'dunk', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 436: {'distance': 20, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 437: {'distance': 19, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 438: {'distance': 10, 'type': 'dunk', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 439: {'distance': 8, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 440: {'distance': 14, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 441: {'distance': 25, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 442: {'distance': 6, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 443: {'distance': 30, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 444: {'distance': 9, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 445: {'distance': 26, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 446: {'distance': 10, 'type': 'dunk', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 447: {'distance': 20, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 448: {'distance': 16, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 449: {'distance': 19, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 450: {'distance': 29, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 451: {'distance': 15, 'type': 'jump shot', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 452: {'distance': 30, 'type': 'layup', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# ...
# Shot 4853: {'distance': 24, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 4854: {'distance': 5, 'type': 'jump shot', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 4855: {'distance': 2, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 4856: {'distance': 12, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 4857: {'distance': 26, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 4858: {'distance': 5, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 4859: {'distance': 19, 'type': 'jump shot', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 4860: {'distance': 2, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 4861: {'distance': 15, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 4862: {'distance': 11, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 4863: {'distance': 13, 'type': 'jump shot', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 4864: {'distance': 13, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 4865: {'distance': 25, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 4866: {'distance': 27, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 4867: {'distance': 29, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 4868: {'distance': 15, 'type': 'dunk', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 4869: {'distance': 21, 'type': 'layup', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 4870: {'distance': 12, 'type': 'layup', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 4871: {'distance': 3, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4872: {'distance': 5, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 4873: {'distance': 6, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 4874: {'distance': 7, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'away'}
# Shot 4875: {'distance': 15, 'type': 'dunk', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 4876: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 4877: {'distance': 23, 'type': 'layup', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 4878: {'distance': 24, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 4879: {'distance': 27, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 4880: {'distance': 25, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 4881: {'distance': 12, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 4882: {'distance': 9, 'type': 'three-pointer', 'defender_distance': 9, 'result': 'missed', 'team': 'away'}
# Shot 4883: {'distance': 26, 'type': 'jump shot', 'defender_distance': 6, 'result': 'missed', 'team': 'away'}
# Shot 4884: {'distance': 9, 'type': 'jump shot', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 4885: {'distance': 23, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 4886: {'distance': 22, 'type': 'dunk', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 4887: {'distance': 1, 'type': 'layup', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 4888: {'distance': 2, 'type': 'dunk', 'defender_distance': 5, 'result': 'missed', 'team': 'home'}
# Shot 4889: {'distance': 3, 'type': 'jump shot', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 4890: {'distance': 12, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 4891: {'distance': 17, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 4892: {'distance': 8, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 4893: {'distance': 26, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 4894: {'distance': 13, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 4895: {'distance': 1, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4896: {'distance': 12, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'away'}
# Shot 4897: {'distance': 14, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 4898: {'distance': 1, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 4899: {'distance': 21, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 4900: {'distance': 12, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4901: {'distance': 21, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 4902: {'distance': 5, 'type': 'jump shot', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 4903: {'distance': 3, 'type': 'layup', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 4904: {'distance': 17, 'type': 'dunk', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 4905: {'distance': 15, 'type': 'layup', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4906: {'distance': 1, 'type': 'layup', 'defender_distance': 10, 'result': 'missed', 'team': 'away'}
# Shot 4907: {'distance': 26, 'type': 'dunk', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 4908: {'distance': 27, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'scored', 'team': 'away'}
# Shot 4909: {'distance': 1, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'away'}
# Shot 4910: {'distance': 12, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 4911: {'distance': 27, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 4912: {'distance': 29, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'away'}
# Shot 4913: {'distance': 20, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 4914: {'distance': 27, 'type': 'layup', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 4915: {'distance': 6, 'type': 'layup', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 4916: {'distance': 17, 'type': 'dunk', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 4917: {'distance': 28, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'missed', 'team': 'home'}
# Shot 4918: {'distance': 3, 'type': 'jump shot', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 4919: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 4920: {'distance': 24, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4921: {'distance': 22, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 4922: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 4923: {'distance': 22, 'type': 'jump shot', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 4924: {'distance': 15, 'type': 'dunk', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 4925: {'distance': 14, 'type': 'jump shot', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 4926: {'distance': 26, 'type': 'jump shot', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 4927: {'distance': 6, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'away'}
# Shot 4928: {'distance': 11, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 4929: {'distance': 2, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 4930: {'distance': 12, 'type': 'jump shot', 'defender_distance': 10, 'result': 'missed', 'team': 'away'}
# Shot 4931: {'distance': 5, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 4932: {'distance': 8, 'type': 'layup', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 4933: {'distance': 3, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'away'}
# Shot 4934: {'distance': 13, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 4935: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 4936: {'distance': 5, 'type': 'layup', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 4937: {'distance': 17, 'type': 'three-pointer', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 4938: {'distance': 16, 'type': 'layup', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 4939: {'distance': 1, 'type': 'dunk', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 4940: {'distance': 13, 'type': 'jump shot', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 4941: {'distance': 21, 'type': 'three-pointer', 'defender_distance': 3, 'result': 'missed', 'team': 'home'}
# Shot 4942: {'distance': 27, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 4943: {'distance': 28, 'type': 'jump shot', 'defender_distance': 1, 'result': 'missed', 'team': 'home'}
# Shot 4944: {'distance': 26, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 4945: {'distance': 7, 'type': 'jump shot', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 4946: {'distance': 28, 'type': 'dunk', 'defender_distance': 8, 'result': 'missed', 'team': 'away'}
# Shot 4947: {'distance': 2, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 4948: {'distance': 20, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'missed', 'team': 'home'}
# Shot 4949: {'distance': 20, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 4950: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'missed', 'team': 'home'}
# Shot 4951: {'distance': 28, 'type': 'jump shot', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 4952: {'distance': 2, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 4953: {'distance': 7, 'type': 'jump shot', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 4954: {'distance': 7, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 4955: {'distance': 19, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 4956: {'distance': 21, 'type': 'jump shot', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 4957: {'distance': 10, 'type': 'three-pointer', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 4958: {'distance': 29, 'type': 'jump shot', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 4959: {'distance': 17, 'type': 'jump shot', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4960: {'distance': 21, 'type': 'jump shot', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 4961: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'home'}
# Shot 4962: {'distance': 1, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4963: {'distance': 22, 'type': 'dunk', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 4964: {'distance': 21, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 4965: {'distance': 16, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 4966: {'distance': 22, 'type': 'jump shot', 'defender_distance': 9, 'result': 'scored', 'team': 'home'}
# Shot 4967: {'distance': 25, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 4968: {'distance': 3, 'type': 'dunk', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4969: {'distance': 15, 'type': 'layup', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}
# Shot 4970: {'distance': 6, 'type': 'three-pointer', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 4971: {'distance': 9, 'type': 'layup', 'defender_distance': 9, 'result': 'scored', 'team': 'away'}
# Shot 4972: {'distance': 19, 'type': 'jump shot', 'defender_distance': 2, 'result': 'scored', 'team': 'away'}
# Shot 4973: {'distance': 29, 'type': 'jump shot', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 4974: {'distance': 13, 'type': 'jump shot', 'defender_distance': 7, 'result': 'scored', 'team': 'home'}
# Shot 4975: {'distance': 16, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 4976: {'distance': 11, 'type': 'jump shot', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 4977: {'distance': 3, 'type': 'jump shot', 'defender_distance': 6, 'result': 'scored', 'team': 'away'}
# Shot 4978: {'distance': 3, 'type': 'dunk', 'defender_distance': 10, 'result': 'scored', 'team': 'home'}
# Shot 4979: {'distance': 5, 'type': 'dunk', 'defender_distance': 4, 'result': 'scored', 'team': 'away'}
# Shot 4980: {'distance': 14, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 4981: {'distance': 12, 'type': 'dunk', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 4982: {'distance': 17, 'type': 'dunk', 'defender_distance': 8, 'result': 'missed', 'team': 'home'}
# Shot 4983: {'distance': 6, 'type': 'dunk', 'defender_distance': 7, 'result': 'missed', 'team': 'away'}
# Shot 4984: {'distance': 11, 'type': 'three-pointer', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 4985: {'distance': 24, 'type': 'three-pointer', 'defender_distance': 6, 'result': 'missed', 'team': 'home'}
# Shot 4986: {'distance': 9, 'type': 'layup', 'defender_distance': 6, 'result': 'missed', 'team': 'away'}
# Shot 4987: {'distance': 26, 'type': 'layup', 'defender_distance': 1, 'result': 'scored', 'team': 'away'}
# Shot 4988: {'distance': 24, 'type': 'layup', 'defender_distance': 3, 'result': 'scored', 'team': 'home'}
# Shot 4989: {'distance': 21, 'type': 'layup', 'defender_distance': 2, 'result': 'scored', 'team': 'home'}
# Shot 4990: {'distance': 3, 'type': 'three-pointer', 'defender_distance': 5, 'result': 'scored', 'team': 'away'}
# Shot 4991: {'distance': 3, 'type': 'jump shot', 'defender_distance': 4, 'result': 'scored', 'team': 'home'}
# Shot 4992: {'distance': 18, 'type': 'dunk', 'defender_distance': 9, 'result': 'missed', 'team': 'home'}
# Shot 4993: {'distance': 9, 'type': 'jump shot', 'defender_distance': 10, 'result': 'missed', 'team': 'away'}
# Shot 4994: {'distance': 5, 'type': 'dunk', 'defender_distance': 1, 'result': 'scored', 'team': 'home'}
# Shot 4995: {'distance': 1, 'type': 'three-pointer', 'defender_distance': 10, 'result': 'missed', 'team': 'home'}
# Shot 4996: {'distance': 14, 'type': 'layup', 'defender_distance': 8, 'result': 'scored', 'team': 'home'}
# Shot 4997: {'distance': 22, 'type': 'dunk', 'defender_distance': 6, 'result': 'scored', 'team': 'home'}
# Shot 4998: {'distance': 16, 'type': 'three-pointer', 'defender_distance': 2, 'result': 'missed', 'team': 'home'}
# Shot 4999: {'distance': 16, 'type': 'dunk', 'defender_distance': 4, 'result': 'missed', 'team': 'away'}
# Shot 5000: {'distance': 20, 'type': 'dunk', 'defender_distance': 5, 'result': 'scored', 'team': 'home'}

# %% [markdown]
# ### 5. Testing the model on random data

# %%
def calculate_xB(shots_data):
    total_xB = 0
    for shot in shots_data:
        xB = calculate_shot_xB(shot)
        total_xB += xB
    return total_xB

def calculate_shot_xB(shot):
    # Perform calculations to determine xB for each shot
    # Factors to consider may include shot distance, shot type, defender proximity, etc.
    xB = 0.5  # Placeholder value, replace with actual calculation
    if shot['result'] == 'scored':
        xB *= calculate_scored_xB(shot)
    else:
        xB *= calculate_missed_xB(shot)

    return xB

def calculate_scored_xB(shot):
    # Perform calculations for xB when the shot is scored
    # Modify the calculation based on the factors specific to scored shots
    xB_scored = 1  # Placeholder value, replace with actual calculation

    return xB_scored

def calculate_missed_xB(shot):
    # Perform calculations for xB when the shot is missed
    # Modify the calculation based on the factors specific to missed shots
    xB_missed = 0.45 # Placeholder value, replace with actual calculation

    return xB_missed

# Example usage
shots_data = shots_data

expected_baskets = calculate_xB(shots_data)
print(f"Expected Baskets: {expected_baskets}")
# Out:
# Expected Baskets: 405.95000000000186

# %% [markdown]
# ### 6. Adding home and away as a metric /sample data code is updated/

# %% [markdown]
# ### 7. Making calculations for expected baskets for home and away team

# %%
def calculate_xB(shots_data):
    total_home_xB = 0
    total_away_xB = 0
    
    for shot in shots_data:
        xB = calculate_shot_xB(shot)
        if shot['team'] == 'home':
            total_home_xB += xB
        elif shot['team'] == 'away':
            total_away_xB += xB
    
    return total_home_xB, total_away_xB

def calculate_shot_xB(shot):
    # Perform calculations to determine xB for each shot
    # Factors to consider may include shot distance, shot type, defender proximity, etc.
    xB = 0.5  # Placeholder value, replace with actual calculation
    if shot['result'] == 'scored':
        xB *= calculate_scored_xB(shot)
    else:
        xB *= calculate_missed_xB(shot)

    return xB

def calculate_scored_xB(shot):
    # Perform calculations for xB when the shot is scored
    # Modify the calculation based on the factors specific to scored shots
    home_factor = 1.2  # Placeholder value, replace with actual calculation
    away_factor = 0.8  # Placeholder value, replace with actual calculation
    xB_scored = 1.0  # Placeholder value, replace with actual calculation

    if shot['team'] == 'home':
        xB_scored *= home_factor
    elif shot['team'] == 'away':
        xB_scored *= away_factor

    return xB_scored

def calculate_missed_xB(shot):
    # Perform calculations for xB when the shot is missed
    # Modify the calculation based on the factors specific to missed shots
    home_factor = 0.9  # Placeholder value, replace with actual calculation
    away_factor = 1.1  # Placeholder value, replace with actual calculation
    xB_missed = 0.35  # Placeholder value, replace with actual calculation

    if shot['team'] == 'home':
        xB_missed *= home_factor
    elif shot['team'] == 'away':
        xB_missed *= away_factor

    return xB_missed

# Example usage
shots_data = shots_data

home_baskets, away_baskets = calculate_xB(shots_data)
print(f"Expected Baskets for Home: {home_baskets}")
print(f"Expected Baskets for Away: {away_baskets}")
# Out:
# Expected Baskets for Home: 1213.7400000000193
# Expected Baskets for Away: 742.3399999999768

# %% [markdown]
# ### 8. Updating calculations with standardizer for the placeholder values

# %%
def calculate_xB(shots_data):
    total_home_xB = 0
    total_away_xB = 0
    
    for shot in shots_data:
        xB = calculate_shot_xB(shot)
        if shot['team'] == 'home':
            total_home_xB += xB
        elif shot['team'] == 'away':
            total_away_xB += xB
    
    return total_home_xB, total_away_xB

def calculate_shot_xB(shot):
    # Perform calculations to determine xB for each shot
    # Factors to consider may include shot distance, shot type, defender proximity, etc.
    xB = 0.5  # Placeholder value, replace with actual calculation
    if shot['result'] == 'scored':
        xB *= calculate_scored_xB(shot)
    else:
        xB *= calculate_missed_xB(shot)

    return xB

def calculate_scored_xB(shot):
    # Perform calculations for xB when the shot is scored
    # Modify the calculation based on the factors specific to scored shots
    home_factor_min = 0.8  # Placeholder value, replace with the actual minimum value
    home_factor_max = 1.2  # Placeholder value, replace with the actual maximum value
    away_factor_min = 0.8  # Placeholder value, replace with the actual minimum value
    away_factor_max = 1.1  # Placeholder value, replace with the actual maximum value
    
    home_factor = 1.0  # Placeholder value, replace with the actual home factor
    away_factor = 1.0  # Placeholder value, replace with the actual away factor
    
    home_factor_std = standardize_value(home_factor, home_factor_min, home_factor_max)
    away_factor_std = standardize_value(away_factor, away_factor_min, away_factor_max)

    xB_scored = 1.0  # Placeholder value, replace with actual calculation

    if shot['team'] == 'home':
        xB_scored *= home_factor_std
    elif shot['team'] == 'away':
        xB_scored *= away_factor_std

    return xB_scored

def calculate_missed_xB(shot):
    # Perform calculations for xB when the shot is missed
    # Modify the calculation based on the factors specific to missed shots
    home_factor_min = 0.5  # Placeholder value, replace with the actual minimum value
    home_factor_max = 1  # Placeholder value, replace with the actual maximum value
    away_factor_min = 0.5 # Placeholder value, replace with the actual minimum value
    away_factor_max = 1  # Placeholder value, replace with the actual maximum value
    
    home_factor = (home_factor_min + home_factor_max) / 2
    away_factor = (away_factor_min + away_factor_max) / 2
    
    home_factor_std = standardize_value(home_factor, home_factor_min, home_factor_max)
    away_factor_std = standardize_value(away_factor, away_factor_min, away_factor_max)

    xB_missed = 0.45  # Placeholder value, replace with actual calculation

    if shot['team'] == 'home':
        xB_missed *= home_factor_std
    elif shot['team'] == 'away':
        xB_missed *= away_factor_std

    return xB_missed

# Example usage
shots_data = shots_data

home_baskets, away_baskets = calculate_xB(shots_data)
print(f"Expected Baskets for Home: {home_baskets}")
print(f"Expected Baskets for Away: {away_baskets}")
# Out:
# Expected Baskets for Home: 550.3500000000039
# Expected Baskets for Away: 579.8999999999976
