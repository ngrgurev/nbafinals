# %%
# %pip install scraper
# %pip install classifier

#%pip install tweepy
#%pip install textblob

import tweepy
from textblob import TextBlob
import pandas as pd

# Twitter API credentials
api_key = "pc3BLOU3REm0cyrh8ERCEt834"
api_secret = "oWqMY6E1KZvTnlJG6dbFoRMSOOH3gPhyT03kCWmPtuHfhM8Y2B"
access_token = "1639304469878824960-drCGPHRw3DfIIoofN8Eqj1Safi9A8y"
access_token_secret = "iV1s61fwPMRkBdNroQ2d4HerEGbzjWhsxMujepAewvVEw"

# Authenticating with Twitter API
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)

# Creating API object
api = tweepy.API(auth)

# Function to scrape NBA comments from Twitter
def scrape_nba_comments():
    nba_comments = []

    # Scraping tweets containing NBA-related keywords
    tweets = tweepy.Cursor(api.search_tweets, q="NBA", tweet_mode="extended").items(1000)

    for tweet in tweets:
        # Checking if the tweet has comments
        if hasattr(tweet, "comments"):
            # Fetching the comments
            comments = tweet.comments()

            for comment in comments:
                # Extracting the comment text
                comment_text = comment.full_text

                # Adding the comment to the list
                nba_comments.append(comment_text)

    return nba_comments

# Scrape NBA comments from Twitter
nba_comments = scrape_nba_comments()

# Perform sentiment analysis on the comments
for comment in nba_comments:
    blob = TextBlob(comment)
    sentiment = blob.sentiment

    # Print the comment and its sentiment
    print("Comment:", comment)
    print("Sentiment: Polarity =", sentiment.polarity, "Subjectivity =", sentiment.subjectivity)
    print()
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[10], line 47
#      44     return nba_comments
#      46 # Scrape NBA comments from Twitter
# ---> 47 nba_comments = scrape_nba_comments()
#      49 # Perform sentiment analysis on the comments
#      50 for comment in nba_comments:
#
# Cell In[10], line 31, in scrape_nba_comments()
#      28 # Scraping tweets containing NBA-related keywords
#      29 tweets = tweepy.Cursor(api.search_tweets, q="NBA", tweet_mode="extended").items(1000)
# ---> 31 for tweet in tweets:
#      32     # Checking if the tweet has comments
#      33     if hasattr(tweet, "comments"):
#      34         # Fetching the comments
#      35         comments = tweet.comments()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\cursor.py:167, in IdIterator.next(self)
#     164     raise StopIteration
#     166 if self.index >= len(self.results) - 1:
# --> 167     data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     169     model = ModelParser().parse(
#     170         data, api = self.method.__self__,
#     171         payload_list=self.method.payload_list,
#     172         payload_type=self.method.payload_type
#     173     )
#     174     result = self.method.__self__.parser.parse(
#     175         data, api = self.method.__self__,
#     176         payload_list=self.method.payload_list,
#     177         payload_type=self.method.payload_type
#     178     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\api.py:1146, in API.search_tweets(self, q, **kwargs)
#    1052 @pagination(mode='id')
#    1053 @payload('search_results')
#    1054 def search_tweets(self, q, **kwargs):
#    1055     """search_tweets(q, *, geocode, lang, locale, result_type, count, \
#    1056                      until, since_id, max_id, include_entities)
#    1057
#    (...)
#    1144     .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1145     """
# -> 1146     return self.request(
#    1147         'GET', 'search/tweets', endpoint_parameters=(
#    1148             'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1149             'until', 'since_id', 'max_id', 'include_entities'
#    1150         ), q=q, **kwargs
#    1151     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\api.py:271, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     269     raise Unauthorized(resp)
#     270 if resp.status_code == 403:
# --> 271     raise Forbidden(resp)
#     272 if resp.status_code == 404:
#     273     raise NotFound(resp)
#
# Forbidden: 403 Forbidden
# 453 - You currently have access to a subset of Twitter API v2 endpoints and limited v1.1 endpoints (e.g. media post, oauth) only. If you need access to this endpoint, you may need a different access level. You can learn more here: https://developer.twitter.com/en/portal/product

# %%
# %pip install textblob


from textblob import TextBlob

# Sample NBA comments
nba_comments = [
    "I love watching NBA games!",
    "The NBA playoffs are so exciting!",
    "I'm not a fan of basketball.",
    "The NBA teams are really talented.",
    "I can't wait for the next NBA season!"
]

# Perform sentiment analysis on the comments
for comment in nba_comments:
    blob = TextBlob(comment)
    sentiment = blob.sentiment

    # Print the comment and its sentiment
    print("Comment:", comment)
    print("Sentiment: Polarity =", sentiment.polarity, "Subjectivity =", sentiment.subjectivity)
    print()
# Out:
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Collecting nltk>=3.1 (from textblob)
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting click (from nltk>=3.1->textblob)
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: joblib in c:\users\grgur\onedrive\desktop\finals\myenv\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Collecting regex>=2021.8.3 (from nltk>=3.1->textblob)
#   Downloading regex-2023.6.3-cp310-cp310-win_amd64.whl (268 kB)
#                                               0.0/268.0 kB ? eta -:--:--
#      -------------                           92.2/268.0 kB 1.7 MB/s eta 0:00:01
#      ------------------------               174.1/268.0 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 268.0/268.0 kB 1.8 MB/s eta 0:00:00
# Collecting tqdm (from nltk>=3.1->textblob)
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: colorama in c:\users\grgur\onedrive\desktop\finals\myenv\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Installing collected packages: tqdm, regex, click, nltk, textblob
# Successfully installed click-8.1.3 nltk-3.8.1 regex-2023.6.3 textblob-0.17.1 tqdm-4.65.0
# Note: you may need to restart the kernel to use updated packages.
# Comment: I love watching NBA games!
# Sentiment: Polarity = 0.625 Subjectivity = 0.6
#
# Comment: The NBA playoffs are so exciting!
# Sentiment: Polarity = 0.375 Subjectivity = 0.8
#
# Comment: I'm not a fan of basketball.
# Sentiment: Polarity = 0.0 Subjectivity = 0.0
#
# Comment: The NBA teams are really talented.
# Sentiment: Polarity = 0.7 Subjectivity = 0.9
#
# Comment: I can't wait for the next NBA season!
# Sentiment: Polarity = 0.0 Subjectivity = 0.0
